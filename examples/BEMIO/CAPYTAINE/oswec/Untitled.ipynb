# %%
import main
# Out:
# [00:01:04] WARNING  Mesh resolution for 8118 problems:
#                     The resolution of the mesh might be insufficient for omega ranging from 5.280 to 20.000.
#                     This warning appears when the largest panel of this mesh has radius > wavelength/8.
# Output()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-63b75181c34a> in <module>
# ----> 1 import main
#
# ~/Documents/GitHub/WEC-Sim_Fork/examples/BEMIO/CAPYTAINE/oswec/main.py in <module>
#      45
#      46 solver = cpt.BEMSolver()
# ---> 47 dataset = solver.fill_dataset(test_matrix, oswec_body.immersed_part(), n_jobs=1)
#      48
#      49 cpt.export_dataset(os.path.join(output_dir, 'oswec_hydrodynamics.nc'), dataset)
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-358d5687b810> in <module>
# ----> 1 __file__
#
# NameError: name '__file__' is not defined
